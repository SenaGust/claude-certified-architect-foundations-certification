# %%
import os
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

auth_token = os.getenv("ANTHROPIC_API_KEY")

client = Anthropic(
    auth_token=auth_token,
    base_url="https://flow.ciandt.com/flow-llm-proxy/"
)

model = "bedrock/anthropic.claude-4-6-sonnet"

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# Start with an empty message list
messages = []

while True:
    user_input = input("You: ")
    add_user_message(messages, user_input)
    claude_answer = chat(messages)
    print("Claude: " + claude_answer)
    add_assistant_message(messages, claude_answer)
# Out:
# You:  what is 1 + 1?
# Claude: 1 + 1 = **2**
# You:  add 3
# Claude: 1 + 1 + 3 = **5**
# You:  what means quantum physics?
# Claude: # Quantum Physics
#
# Quantum physics (also called **quantum mechanics**) is a branch of physics that studies the behavior of matter and energy at the **smallest scales** - like atoms, electrons, and photons.
#
# ## Key Ideas:
#
# - **Wave-particle duality** - particles like electrons can behave as both a wave and a particle
# - **Superposition** - a particle can exist in multiple states at the same time until it is observed/measured
# - **Uncertainty principle** - you cannot know both the exact position and speed of a particle at the same time (Heisenberg)
# - **Quantum entanglement** - two particles can be connected so that what happens to one instantly affects the other, no matter how far apart they are
#
# ## In Simple Terms:
# At the **very small scale**, the rules of physics are very different from everyday life. Things can be in multiple places at once, and simply **observing** something can change it.
#
# ## Why it matters:
# Quantum physics is the foundation for many modern technologies, such as:
# - Computers and transistors
# - Lasers
# - MRI machines
# - Quantum computers (emerging technology)
#
# It is one of the most **successful but mysterious** theories in all of science! 🔬
# You:  what is the first message that I sent to you?
# Claude: Your first message to me was:
#
# **"what is 1 + 1?"**
