# %%
import os
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

auth_token = os.getenv("ANTHROPIC_API_KEY")

client = Anthropic(
    auth_token=auth_token,
    base_url="https://flow.ciandt.com/flow-llm-proxy/"
)

model = "bedrock/anthropic.claude-4-6-sonnet"

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

messages = []
add_user_message(messages, "Write a 1 sentence description of a fake database")


## First way
# stream = client.messages.create(
#     model=model,
#     max_tokens=1000,
#     messages=messages,
#     stream=True
# )

# for event in stream:
#     print(event)

## Second way
with client.messages.stream(
    model=model,
    max_tokens=1000,
    messages=messages
) as stream:
    for text in stream.text_stream:
        print(text, end="")
# Out:
# Here#oi# is a one sentence description of a fake database:
#
# **"Nova#oi#Base is a fictional cloud-based database management system that stores and organizes data for the#oi# made-up corporation Apex Industries, containing thousands of fabric#oi#ated employee records, inventory logs, and financial transactions."**#oi#
